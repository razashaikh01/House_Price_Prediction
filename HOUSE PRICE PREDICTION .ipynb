# %% [markdown]
# # USA HOUSE PRICE PREDICTION MODEL

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
import raza_stats as rs  #here i have created my own module for performing descriptive statistics on the data

# %% [markdown]
# ## READING AND ANALYZING THE DATA

# %%
df = pd.read_csv('USA_Housing.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
df.head(3)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
#
#    Avg. Area Number of Bedrooms  Area Population        Price
# 0                          4.09      23086.80050  1059033.558
# 1                          3.09      40173.07217  1505890.915
# 2                          5.13      36882.15940  1058987.988

# %%
df.tail(3)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population        Price
# 4997                          2.13      33266.14549  1030729.583
# 4998                          5.44      42625.62016  1198656.872
# 4999                          4.07      46501.28380  1298950.480

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
for col_name in df.columns:
    print(col_name)
    rs.cal_stats(col_name,df[col_name])
    print('-'*50)
# Out:
# Avg. Area Income
# Avg. Area Income
# Total Sum 342915544.91985
# Total Count 5000
# Minimum 17796.63119
# Maximum 107701.7484
# Range 89905.12
# Average 68583.11
# Median 68804.29
# Mode ModeResult(mode=np.float64(17796.63119), count=np.int64(1))
# Q1 61480.56239
# Q3 75783.33866499999
# IQR 14302.77627499999
# Lower Whisker 40026.39797750002
# Upper Whisker 97237.50307749998
# Variance 113570058.1599854
# Standard Deviation 10656.925361472013
# Skewness -0.03370985850476661
# Kurtosis 0.044328500390600656
# --------------------------------------------------
# Avg. Area House Age
# Avg. Area House Age
# Total Sum 29886.110176435002
# Total Count 5000
# Minimum 2.644304186
# Maximum 9.519088066
# Range 6.87
# Average 5.98
# Median 5.97
# Mode ModeResult(mode=np.float64(2.644304186), count=np.int64(1))
# Q1 5.32228301575
# Q3 6.65080847925
# IQR 1.3285254635000001
# Lower Whisker 3.3294948205
# Upper Whisker 8.6435966745
# Variance 0.9827887594565956
# ...

# %%
for col_name in df.columns:
    print(col_name)
    sns.displot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.kdeplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.violinplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %% [markdown]
# #### AS THE DATA IS CLEAN AND PERFECT FOR MAKING THE MODEL NOW MOVING FORWARD

# %% [markdown]
# ## CREATING A HEATMAP FOR UNDERSTANDING THE CORRELATION BETWEEN THE COLUMNS

# %%
sns.heatmap(df.corr(),annot=True, vmin=-1,vmax=1, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## NOW CREATING THE MODEL FOR PREDICTING THE HOUSE PRICES

# %%
x=df.drop('Price',axis=1)

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 4000

# %%
len(x_test)
# Out:
# 1000

# %%
len(y_train)
# Out:
# 4000

# %%
len(y_test)
# Out:
# 1000

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([2.14513946e+01, 1.65208742e+05, 1.21359896e+05, 7.00048404e+02,
#        1.53228635e+01])

# %%
lr.intercept_
# Out:
# np.float64(-2631470.6680148467)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 267863.00051639,  799761.01341422, 1437500.86177366,
#        1666453.79077714, 1085610.48670226, 1096743.76186741,
#         471308.46596814, 1300149.60523534, 1258067.58390769,
#        1021172.87174518, 1123710.55498568, 1239862.67462192,
#        1253495.23248673, 1225644.38801161,  876856.87688751,
#        1688882.18124313, 1263856.15834982,  876791.12213406,
#        1544565.84655246, 1526978.29088814, 1264363.52142103,
#        1418648.8434945 ,  534706.15164975, 1359814.72478963,
#        1888800.75877165, 1412201.59287817,  839639.22010174,
#        1276626.82424871,  936906.74866299, 1231988.92620723,
#        1368337.85414028, 1702657.20746413, 1026904.48158118,
#         853068.76815618,  891766.20653404, 1250879.5834324 ,
#         860247.62871407, 1415999.22770396,  664200.94462077,
#        1577181.38830419, 1120361.70971752, 1949314.22937983,
#         963184.03987438, 1231302.98252315, 1632629.46184824,
# ...

# %%
sse = sum((y_pred-y_test)**2)
print('SUM OF SQUARED ERROR:',sse)

mse = np.mean((y_pred-y_test)**2)
print('MEAN OF SQUARED ERROR:',mse)

rmse = np.sqrt(mse)
print('ROOT MEAN OF SQUARED ERROR:',rmse)
# Out:
# SUM OF SQUARED ERROR: 10338511441598.396
# MEAN OF SQUARED ERROR: 10338511441.598396
# ROOT MEAN OF SQUARED ERROR: 101678.47088542586

# %%
df['Price'].mean()
# Out:
# np.float64(1232072.6541453)

# %%
sns.displot(y_pred-y_test)

# %% [markdown]
# #### BY THIS DISPLOT WE CAN SEE THAT OUR MODEL IS PREDICTING ALMOST ACCURATE PRICES
